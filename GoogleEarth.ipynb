# %% [markdown]
# # Get location data from Google Earth

# %%
import googlemaps
import pandas as pd
import numpy as np

# %% [markdown]
# Functions to extract latitude, longitude and to calculate distance between 2 coordinates

# %%
def getLatLng(geocode_result):
    """Extracts the latitude and longitude from a geocode_result variable

    Arguments:
        geocode_result -- generated by googlemaps.client using its geocode method

    Returns:
        tuple (latitude, longitude)
    """
    loc = geocode_result[0]['geometry']['location']
    lat = loc['lat']
    lng = loc['lng']
    return (lat, lng)

def getDist(coords1, coords2, units=None):
    """Calculates distance between 2 coordinates using the Vicenty formula
    
    Arguments:
        coords1, coords2 -- tuples of the format (latitude, longitude)
        units -- pass str 'miles' to get distance in miles
    
    Returns:
        Distance between coords1 and coords2 in miles or kilometers
    """
    import geopy.distance
    if units == 'miles':
        return (geopy.distance.vincenty(coords1, coords2).miles)
    else:
        return (geopy.distance.vincenty(coords1, coords2).km)

# %%
def populateLatLng(df, gmaps, addr_col_name):
    """Adds columns latitude, longitude and distance from reference coords to provided pandas dataframe
    
    Arguments:
        df -- pandas dataframe with formatted institution information
        gmaps -- a googlemaps.client object
        addr_col_name -- str with name of the column that should be used to query address
    
    Returns:
        dataframe with added columns as specified above
    """
    ref_coords = (-23.5999515, -46.7150129) # HOSPITAL ISRAELITA ALBERT EINSTEIN
    latLngDist = np.zeros((df.shape[0], 3))
    latLngDist[:] = np.nan
    for index, row in df.iterrows():
        inst = row[addr_col_name]
        geocode = []
        geocode = gmaps.geocode(inst)
        if geocode == []:
            continue
        lat, lng = getLatLng(geocode)
        dist = getDist(ref_coords, (lat, lng), 'km')
        latLngDist[index, :] = [lat, lng, dist]
    df['Lat'] = latLngDist[:,0]
    df['Lng'] = latLngDist[:,1]
    df['Dist'] = latLngDist[:,2]
    return df

# %% [markdown]
# ## main()
# The api_key provided here was generated by sumanthsridhar.009@gmail.com

# %% [markdown]
# Initialize:

# %%
api_key='AIzaSyDFGsAhv47KwjjXtKlfquu7e_Ag5eQOrgg'
gmaps = googlemaps.Client(key=api_key)
if 'data' not in locals():
    print('Data not present in workspace... importing from local csv')
    data = pd.read_csv('Example02.csv')
# Out:
# Data not present in workspace... importing from local csv

# %% [markdown]
# Execute:
# (NOTE: Takes a couple of minutes to execute. Be patient)

# %%
df = populateLatLng(data, gmaps, 'Complete Address')

# %%
print(df)
# Out:
#     Unnamed: 0                                        Institution  CNES Code  \
# 0            0                          A C CAMARGO CANCER CENTER    2077531
# 1            1     A MAIS MEDICINA DIAGNOSTICA UNID AUGUSTO TOLLE    9227571
# 2            2     A MAIS MEDICINA DIAGNOSTICA UNIDADE CAMPO BELO    6441106
# 3            3          A MAIS MEDICINA DIAGNOSTICA UNIDADE MOEMA    5167612
# 4            4                               AFIP VILA CLEMENTINO    3813517
# 5            5  AME AMBULATORIO MEDICO DE ESPEC DRA MARIA CRIS...    6432530
# 6            6                             BETA SAUDE SANTO AMARO    9096159
SALOMAO E ZOPPI MEDICINA DIAGNOSTICA MORUMBI    5255414
# 57          57       SALOMAO E ZOPPI MEDICINA DIAGNOSTICA PARAISO    7095031
# 58          58  SALOMAO E ZOPPI MEDICINA DIAGNOSTICA PORTAL DO...    7079060
# 59          59       SALOMAO E ZOPPI MEDICINA DIAGNOSTICA SANTANA    7557345
# 60          60       SALOMAO E ZOPPI MEDICINA DIAGNOSTICA TATUAPE    7457723
# 61          61  SALOMAO E ZOPPI MEDICINA DIAGNOSTICA VILA MARIANA    7557353
# 62          62                         SALUS MEDICINA DIAGNOSTICA    9228187
# 63          63  SANTA CASA DE SAO PAULO HOSPITAL CENTRAL SAO P...    2688689
# 64          64                          SAUDIMAGEM CLINICA MEDICA    9036245
# 65          65                                    SR DIAGNOSTICOS    7496575
# 66          66                      UBS UNIAO DAS VILAS DE TAIPAS    2788667
# 67          67                     UNID AVANCADA EINSTEIN JARDINS    3424561
# 68          68                 UNIDADE AVANCADA EINSTEIN PERDIZES    6569757
# 69          69                                     VAS RADIOLOGIA    7464797
#
#     Number of Equipments Accept SUS patients?             Equipment Name  \
# 0                      3                    Y  MAMOGRAFO COMPUTADORIZADO
# 1                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 2                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 3                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 4                      1                    Y  MAMOGRAFO COMPUTADORIZADO
# 5                      1                    Y  MAMOGRAFO COMPUTADORIZADO
# 6                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 7                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 8                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 9                      2                    N  MAMOGRAFO COMPUTADORIZADO
# 10                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 11                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 12                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 13                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 14                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 15                     2                    Y  MAMOGRAFO COMPUTADORIZADO
# 16                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 17                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 18                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 19                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 20                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 21                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 22                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 23                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 24                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 25                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 26                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 27                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 28                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 29                     1                    N  MAMOGRAFO COMPUTADORIZADO
# ..                   ...                  ...                        ...
# 40                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 41                     2                    N  MAMOGRAFO COMPUTADORIZADO
# 42                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 43                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 44                     2                    N  MAMOGRAFO COMPUTADORIZADO
# 45                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 46                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 47                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 48                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 49                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 50                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 51                     2                    N  MAMOGRAFO COMPUTADORIZADO
# 52                     0                    N  MAMOGRAFO COMPUTADORIZADO
# 53                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 54                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 55                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 56                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 57                     3                    N  MAMOGRAFO COMPUTADORIZADO
# 58                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 59                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 60                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 61                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 62                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 63                     2                    Y  MAMOGRAFO COMPUTADORIZADO
# 64                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 65                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 66                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 67                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 68                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 69                     1                    N  MAMOGRAFO COMPUTADORIZADO
#
#             CNPJ                                   Street  Zip Code  Number  \
# 0   6.096197e+13           RUA PROFESSOR ANTONIO PRUDENTE   1509900     211
# 1   6.084006e+13                        RUA AUGUSTO TOLLE   2405000     434
# 2   6.084006e+13                 RUA BERNARDINO DE CAMPOS   4620000     182
# 3   6.084006e+13                          AV INDIANOPOLIS   4062001     922
# 51                 RUA PADRE ESTEVAO PERNET 551
# 52                        AVENIDA ANGELICA 2251
# 53                  AVENIDA DIVINO SALVADOR 856
# 54                         RUA CERRO CORRA 1044
# 55                             RUA ARAGUARI 552
# 56                                R ALGEMESI 76
# 57                          RUA CORREIA DIAS 40
# 58  RUA PROFESSOR HILARIO VEIGA DE CARVALHO 312
# 59            AVENIDA LEONCIO DE MAGALHAES 1133
# 60                      PRACA SILVIO ROMERO 191
# 61                RUA DOUTOR DIOGO DE FARIA 772
# 62        AV RAIMUNDO PEREIRA DE MAGALHAES 5762
# 63                  RUA DR CESARIO MOTTA JR 112
# 64                      RUA BARAO DE DUPRAT 250
# 65                                RUA SIRIA 100
# 66                AV ELISIO TEIXEIRA LEITE 7703
# 67                                  AV BRASIL
# 68                               RUA APIACAS 85
# 69                          RUA BOM SUCESSO 348
#
#                                      Institution Type Specialization  \
# 0                              HOSPITAL ESPECIALIZADO      ONCOLOGIA
# 1   UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 2   UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 3   UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 4   UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 5                                         POLICLINICA            NaN
# 6   UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 7                     CLINICA/CENTRO DE ESPECIALIDADE         OUTROS
# 8   UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 9   UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 10                    CLINICA/CENTRO DE ESPECIALIDADE         OUTROS
# 11                    CLINICA/CENTRO DE ESPECIALIDADE         OUTROS
# 12  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 13                    CLINICA/CENTRO DE ESPECIALIDADE         OUTROS
# 14  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 15  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 16  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 17  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 18  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 19  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 20  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 21  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 22  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 23  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 24  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 25  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 26  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 27  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 28  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 29  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# ..                                                ...            ...
# 40                                     HOSPITAL GERAL            NaN
# 41                                     HOSPITAL GERAL            NaN
# 42                                     HOSPITAL GERAL            NaN
# 43                                     HOSPITAL GERAL            NaN
# 44                                     HOSPITAL GERAL            NaN
# 45  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 46                             HOSPITAL/DIA - ISOLADO            NaN
# 47                             HOSPITAL ESPECIALIZADO      ONCOLOGIA
# 48                    CLINICA/CENTRO DE ESPECIALIDADE         OUTROS
# 49  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 50                    CLINICA/CENTRO DE ESPECIALIDADE         OUTROS
# 51                    CLINICA/CENTRO DE ESPECIALIDADE         OUTROS
# 52  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 53  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 54  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 55  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 56  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 57  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 58  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 59  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 60  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 61  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 62                                        POLICLINICA            NaN
# 63                                     HOSPITAL GERAL            NaN
# 64  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 65  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 66                     CENTRO DE SAUDE/UNIDADE BASICA            NaN
# 67  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
# 68                                     HOSPITAL GERAL            NaN
# 69  UNIDADE DE APOIO DIAGNOSE E TERAPIA (SADT ISOL...            NaN
#
#           Lat         Lng          Dist
# 0  -23.565181  -46.637562      8.793972
# 1  -23.489437  -46.631991     14.888621
# 2  -23.623045  -46.683026      4.147029
# 3  -23.606855  -46.653427      6.331811
# 4  -23.596437  -46.641515      7.511671
# 5  -23.703560  -46.691575     11.721508
# 6  -23.639771  -46.697181      4.770803
# 7  -23.620407  -46.639969      7.986680
# 8  -23.502094  -46.627145     14.069362
# 9  -22.906778  -43.297777    358.002519
# 10 -23.639088  -46.696539      4.726739
# 11  37.652208 -122.087172  10386.801725
# 12 -23.564859  -46.661819      6.677482
# 13 -23.556895  -46.447142     27.757074
# 14 -23.677290  -46.685364      9.084007
# 15 -23.556704  -46.656793      7.632980
# 16 -23.540236  -46.571943     16.033195
# 17 -23.573456  -46.643885      7.830871
# 18 -23.558893  -46.663449      6.955846
# 19 -23.549192  -46.554644     17.309335
# 20 -23.567284  -46.674902      5.463890
# 21 -23.504227  -46.640952     13.022009
# 22 -23.617281  -46.675646      4.452530
# 23 -23.549946  -46.658758      7.978083
# 24 -25.534067  -54.587176    825.569295
# 25 -23.608872  -46.726901      1.564648
# 26 -23.568727  -46.645612      7.883157
# 27 -23.585592  -46.663446      5.498422
# 28 -23.589131  -46.665010      5.242514
# 29 -23.586248  -46.663588      5.463908
# ..        ...         ...           ...
# 40 -23.607482  -46.595690     12.206710
# 41 -23.597018  -46.715672      0.331835
# 42 -23.507589  -46.568956     18.083571
# 43 -23.567167  -46.641490      8.337112
# 44 -23.557083  -46.654490      7.791780
# 45 -23.573327  -46.668079      5.625487
# 46 -23.584969  -46.674910      4.416841
# 47 -23.555972  -46.668151      6.827060
# 48 -23.555179  -46.555838     16.988522
# 49 -23.554004  -46.639785      9.212398
# 50 -23.526134  -46.714104      8.175971
# 51 -23.542107  -46.569461     16.181094
# 52 -23.552147  -46.660532      7.678703
# 53 -23.609221  -46.654769      6.233602
# 54 -23.553236  -46.353770     37.237502
# 55 -23.600786  -46.672730      4.316490
# 56 -23.635059  -46.733298      4.312821
# 57 -23.658585  -46.525623     20.387427
# 58 -23.616371  -46.739027      3.051787
# 59 -23.491445  -46.618451     15.544354
# 60 -23.544952  -46.572711     15.752327
# 61 -23.595471  -46.644192      7.245395
# 62 -23.481706  -46.723297     13.123184
# 63 -23.542654  -46.650545      9.142308
# 64 -23.655042  -46.702809      6.227235
# 65 -23.532789  -46.565809     16.951361
# 66 -23.435644  -46.718084     18.200028
# 67 -22.861173  -43.452495    343.778247
# 68 -23.533367  -46.675519      8.404639
# 69 -23.543638  -46.576803     15.426193
#
# [70 rows x 16 columns]

# %%
df.to_csv('with_latlng.csv')

# %%
try:
    import gmaps
except ImportError:
    import sys
    # !conda install --yes --prefix {sys.prefix} -c conda-forge gmaps
    import gmaps
import gmaps.datasets

# %%
def map_competitors(df, ref_row, max_dist):
    max_dist=10
    api_key_2 = 'AIzaSyBiFncz_ygbcJQCsm84VK1hljtQ26UGsAo'
    gmaps.configure(api_key_2)
    competitors_df = df[df['Dist'] < max_dist]
    locations_df = competitors_df[['Lat', 'Lng']]
    competitor_names = list(competitors_df['Institution'])
    competitors_layer = gmaps.symbol_layer(locations=locations_df,
                                           hover_text=competitor_names,
                                           fill_color='green',
                                           stroke_color='green',
                                           scale=2)
    ref_coords = ref_row[['Lat','Lng']]
    marker = gmaps.marker_layer(locations=ref_coords, 
                                hover_text=ref_row.iloc[0]['Institution'])
    fig = gmaps.figure()
    fig.add_layer(marker)
    fig.add_layer(competitors_layer)
    return fig

# %%
ref_name = 'HOSPITAL ISRAELITA ALBERT EINSTEIN'
ref_row = df.loc[df['Institution'] == ref_name]
fig = map_competitors(df, ref_row, max_dist=10)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
