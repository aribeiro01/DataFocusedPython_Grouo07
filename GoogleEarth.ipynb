# %% [markdown]
# # Get location data from Google Earth

# %%
import googlemaps
import pandas as pd
import numpy as np

# %% [markdown]
# Functions to extract latitude, longitude and to calculate distance between 2 coordinates

# %%
def getLatLng(geocode_result):
    """Extracts the latitude and longitude from a geocode_result variable

    Arguments:
        geocode_result -- generated by googlemaps.client using its geocode method

    Returns:
        tuple (latitude, longitude)
    """
    loc = geocode_result[0]['geometry']['location']
    lat = loc['lat']
    lng = loc['lng']
    return (lat, lng)

def getDist(coords1, coords2, units=None):
    """Calculates distance between 2 coordinates using the Vicenty formula
    
    Arguments:
        coords1, coords2 -- tuples of the format (latitude, longitude)
        units -- pass str 'miles' to get distance in miles
    
    Returns:
        Distance between coords1 and coords2 in miles or kilometers
    """
    import geopy.distance
    if units == 'miles':
        return (geopy.distance.vincenty(coords1, coords2).miles)
    else:
        return (geopy.distance.vincenty(coords1, coords2).km)

# %%
def populateLatLng(df, gmaps):
    """Adds columns latitude, longitude and distance from reference coords to provided pandas dataframe
    
    Arguments:
        df -- pandas dataframe with formatted institution information
        gmaps -- a googlemaps.client object
    
    Returns:
        dataframe with added columns as specified above
    """
    ref_coords = (-23.5999515, -46.7150129) # HOSPITAL ISRAELITA ALBERT EINSTEIN
    latLngDist = np.zeros((df.shape[0], 3))
    latLngDist[:] = np.nan
    for index, row in df.iterrows():
        inst = row['Institution']
        geocode = []
        geocode = gmaps.geocode(inst)
        if geocode == []:
            continue
        lat, lng = getLatLng(geocode)
        dist = getDist(ref_coords, (lat, lng), 'miles')
        latLngDist[index, :] = [lat, lng, dist]
    df['Lat'] = latLngDist[:,0]
    df['Lng'] = latLngDist[:,1]
    df['Miles from Ref'] = latLngDist[:,2]
    return df

# %% [markdown]
# ## main()
# The api_key provided here was generated by sumanthsridhar.009@gmail.com

# %%
api_key='AIzaSyDFGsAhv47KwjjXtKlfquu7e_Ag5eQOrgg'
gmaps = googlemaps.Client(key=api_key)
df = pd.read_csv('Example.csv')
df = populateLatLng(df, gmaps)

# %%
print(df)
# Out:
#     Unnamed: 0                                        Institution  CNES Code  \
# 0            0                          A C CAMARGO CANCER CENTER    2077531
# 1            1     A MAIS MEDICINA DIAGNOSTICA UNID AUGUSTO TOLLE    9227571
# 2            2     A MAIS MEDICINA DIAGNOSTICA UNIDADE CAMPO BELO    6441106
# 3            3          A MAIS MEDICINA DIAGNOSTICA UNIDADE MOEMA    5167612
# 4            4                               AFIP VILA CLEMENTINO    3813517
# 5            5  AME AMBULATORIO MEDICO DE ESPECIALIDADES INTER...    6432530
# 6            6                             BETA SAUDE SANTO AMARO    9096159
# 7            7                                     BFA RADIOLOGIA    7931212
# 8            8  CARDIOLOGICA MEDICINA DIAGNOSTICA SERV MED E A...    3156877
# 9            9            CENTRO AVANCADO DE MEDICINA DIAGNOSTICA    7469691
# 10          10            CENTRO DE PROCEDIMENTO E APOIO ZONA SUL    7823339
# 11          11   CENTRO MEDICO LIBERDADE HOSPITAL NIPO BRASILEIRO    3893723
# 12          12     CIMERMAN ANALISES CLINICAS UNIDADE JD PAULISTA    3042472
# 13          13        CRUZ AZUL DE SAO PAULO AMBULATORIO ITAQUERA    6312853
# 14          14                           DAITEBI SERVICOS MEDICOS    7457677
# 15          15                                             DIMEDI    3306704
# 16          16                        FEMME LABORATORIO DA MULHER    7593589
# 17          17                   FLEURY MEDICINA E SAUDE UNID JAU    9199942
      1                    N  MAMOGRAFO COMPUTADORIZADO
# 7                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 8                      1                    N  MAMOGRAFO COMPUTADORIZADO
# 9                      2                    N  MAMOGRAFO COMPUTADORIZADO
# 10                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 11                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 12                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 13                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 14                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 15                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 16                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 17                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 18                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 19                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 20                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 21                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 22                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 23                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 24                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 25                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 26                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 27                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 28                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 29                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# ..                   ...                  ...                        ...
# 37                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 38                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 39                     2                    N  MAMOGRAFO COMPUTADORIZADO
# 40                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 41                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 42                     0                    N  MAMOGRAFO COMPUTADORIZADO
# 43                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 44                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 45                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 46                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 47                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 48                     2                    N  MAMOGRAFO COMPUTADORIZADO
# 49                     0                    N  MAMOGRAFO COMPUTADORIZADO
# 50                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 51                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 52                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 53                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 54                     3                    N  MAMOGRAFO COMPUTADORIZADO
# 55                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 56                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 57                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 58                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 59                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 60                     2                    Y  MAMOGRAFO COMPUTADORIZADO
# 61                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 62                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 63                     1                    Y  MAMOGRAFO COMPUTADORIZADO
# 64                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 65                     1                    N  MAMOGRAFO COMPUTADORIZADO
# 66                     1                    N  MAMOGRAFO COMPUTADORIZADO
#
#           Lat        Lng  Miles from Ref
# 0  -23.565299 -46.635979        5.551283
# 1  -23.489486 -46.632078        9.245430
# 2  -23.622901 -46.682797        2.582264
# 3  -23.613586 -46.741008        1.896842
# 4  -23.596437 -46.641515        4.667536
# 5  -23.703527 -46.691843        7.277726
# 6  -23.639771 -46.697181        2.964440
# 7         NaN        NaN             NaN
# 8  -23.502094 -46.627145        8.742297
# 9         NaN        NaN             NaN
# 10        NaN        NaN             NaN
# 11 -23.559370 -46.636128        5.730233
# 12 -23.564681 -46.661850        4.154763
# 13 -23.556789 -46.446969       17.259544
# 14 -23.677205 -46.685421        5.637804
# 15 -23.540267 -46.572138        9.950416
# 16 -23.574913 -46.643969        4.824222
# 17 -23.558888 -46.663447        4.322483
# 18 -23.549189 -46.554644       10.755635
# 19 -23.504209 -46.640956        8.092392
# 20 -23.617401 -46.675465        2.780620
# 21 -23.585816 -46.682626        2.272783
# 22 -23.567284 -46.674902        3.395104
# 23 -23.608200 -46.726104        0.903851
# 24 -23.589143 -46.664988        3.258711
# 25 -23.623468 -46.700389        1.865239
# 26 -23.631785 -46.735570        2.549235
# 27 -23.540072 -46.676043        4.805368
# 28 -23.554588 -46.716427        3.123150
# 29 -23.602605 -46.610806        6.611215
# ..        ...        ...             ...
# 37 -23.507339 -46.568937       11.247354
# 38 -23.567234 -46.641478        5.179122
# 39 -34.590045 -58.507299     1038.411240
# 40 -23.573521 -46.668139        3.485320
# 41 -23.584969 -46.674910        2.744497
# 42 -23.496824 -46.625951        9.071657
# 43 -23.555972 -46.668151        4.242138
# 44        NaN        NaN             NaN
# 45 -23.554003 -46.639744        5.726538
# 46 -23.526046 -46.714104        5.086340
# 47 -23.546679 -46.633308        6.348326
# 48 -23.536313 -46.560279       10.748243
# 49        NaN        NaN             NaN
# 50        NaN        NaN             NaN
# 51        NaN        NaN             NaN
# 52 -23.576915 -46.642582        4.859797
# 53 -23.576915 -46.642582        4.859797
# 54        NaN        NaN             NaN
# 55        NaN        NaN             NaN
# 56        NaN        NaN             NaN
# 57        NaN        NaN             NaN
# 58 -23.576915 -46.642582        4.859797
# 59 -23.486812 -46.726080        7.817614
# 60 -23.542777 -46.649778        5.710087
# 61 -23.957042 -46.331981       34.531290
# 62 -23.542255 -46.569508       10.047663
# 63 -23.435644 -46.718084       11.308973
# 64 -23.584687 -46.663388        3.438596
# 65 -23.533367 -46.675519        5.222400
# 66        NaN        NaN             NaN
#
# [67 rows x 9 columns]
